# %%
#Vamos a crear uan tienda llamada tienda on line que cumple los siguientes requisitos
#tiene estos atributos ;inventario  y ventas totales
#inventario es igual a una lista de diccionarios con las claves;nombre, precio y cantidad

# %%
#esta es la clase en la que voy a ir añadiendo una vez hecha los metodos

# %%
class TiendaOnLine():#es de buena practica poner mayuscula en las clases
    def __init__(self):
        self.atributo=[{'nombre':'camisa','precio':20,'cantidad':40}]
        self.ventas_totales=self.ventas_totales


        pass

# %%
#  METODOS

# %%
#1.agregar_producto (self,nombre,precio,cantidad)
#agrega un producto a un inventario o actualiza su cantidad si ya existe
#debe tener nombre, precio y cantidad de producto como parametros
#itera a traves del inventario y compara los nombres (para iterar, bucle for)
#si el producto ya existe actualiza (asigancion directa)
#si no existe agrega uno nuevo

def agregar_producto(self, nombre, precio, cantidad):
    for nombre in self.atributo:
        if nombre == self.atributo:
            print(f' el producto {nombre}, ya exixte')
        else:
            print(f'el producto {nombre},es nuevo ya queda agregado')

# %%
#creo una tienda egocentrista para comprobar que todo se va ejecutando

tienda_sara=TiendaOnLine('pantalon',30,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #creo una tienda egocentrista para comprobar que todo se va ejecutando
# ----> 3 tienda_sara=TiendaOnLine('pantalon',30,30)
#
# TypeError: TiendaOnLine.__init__() takes 1 positional argument but 4 were given
