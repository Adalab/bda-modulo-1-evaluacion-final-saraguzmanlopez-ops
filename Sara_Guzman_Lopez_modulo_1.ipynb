# %%
#Vamos a crear uan tienda llamada tienda on line que cumple los siguientes requisitos
#tiene estos atributos ;inventario  y ventas totales
#inventario es igual a una lista de diccionarios con las claves;nombre, precio y cantidad

# %%
#esta es la clase en la que voy a ir añadiendo una vez hecha los metodos

# %%
class TiendaOnLine():#es de buena practica poner mayuscula en las clases
   
   def __init__(self,nombre):
        self.nombre=nombre
        self.inventario=[{'nombre':'camisa','precio':20,'cantidad':40}]
        self.ventas_totales=0.0

    
   def agregar_producto(self,nombre,precio,cantidad):
      producto_nuevo={'nombre':nombre,'precio':precio,'cantidad':cantidad}
      for producto in self.inventario:
      
         if nombre == producto['nombre']:
             print('este producto ya estaba no puedes volver a agregarlo')
             break

      else:
               self.inventario.append(producto_nuevo)       
               print(f'el producto {nombre} , ha sido agregado') 

 
               

   def ver_inventario(self):
      for producto in self.inventario:
         print(f'Nombre: {producto['nombre']}, Precio : {producto['precio']} $, Cantida: {producto['cantidad']}')
        



   def buscar_producto(self,nombre):
       for producto in self.inventario:
           if nombre==producto['nombre']:
               print(f'Nombre: {producto['nombre']}, Precio $: {producto['precio']}, Cantida: {producto['cantidad']}')
            
               break
       

           else:
            print(f'el "producto" , no esta entre las opciones')
            break



  
   def actualizar_stock(self,nombre,cantidad):
      
      
      for producto in self.inventario:
         pregunta=(input("que producto quieres actualizar? "))

         if pregunta.lower() == producto['nombre']: 
            print (f'quieres modificar el producto, {pregunta}')

      
         
            pregunta2=(input("a que cantidad la quieres actualizar? "))
            producto['cantidad'] = int(pregunta2)
            encontrado = True
            print(f"Stock actualizado. Nueva cantidad de {nombre}: es  {producto['cantidad']}")

            print('mi stock actual es: ')

            print(f'Nombre: {producto['nombre']}, Precio : {producto['precio']} $, Cantida: {producto['cantidad']}')
            break

         else:
                  print(f'el producto , {pregunta} , no esta en el inventario revisalo porfa')
                  break
         
         print('mi stock actual es: ')

         print(f'Nombre: {producto['nombre']}, Precio : {producto['precio']} $, Cantida: {producto['cantidad']}')





   def eliminar_producto(self, nombre):
            encontrado = False
            for producto in self.inventario:
                  if producto['nombre'].lower() == nombre.lower():
                     # Eliminamos el diccionario encontrado de la lista
                     self.inventario.remove(producto)
                     encontrado = True
                     print(f"Producto '{nombre}' eliminado exitosamente.")
                     break # Salimos del bucle tras eliminar para evitar errores de iteración
            
            else:
                  print(f"No se encontró el producto '{nombre}', no se pudo eliminar.")
                  



   def calcular_valor_inventario(self):
    valor_total=0 #variable vacia que recibira la multiplicacion de cantidad y precio

    #iteramos 
    for producto in self.inventario:

        valor_producto=producto['precio']*producto['cantidad']# como va a iterar, aqui paran cada uno de las multiplicaciones e cada producto

        valor_total+=valor_producto #es la suma de todas las multiplicaciones de valor producto

        print(f'el valor total de todo el "inventario es: {valor_total} €')
        return valor_total

# %%
# ejercicio 1. 
# agregar_producto(self, nombre, precio, cantidad): 
# Este método agrega un producto al inventario o actualiza su cantidad si ya existe.
#  Debe recibir el nombre, precio y cantidad del productocomo parámetros.
#Itera a través del inventario y compara los nombres de los productos con el nombre
#Si el producto ya existe, actualiza la cantidad.
#Si no existe, agrega un nuevo producto al inventario

#para hacer esto , a como habla de iterar es un for , para encontrar el value de cada dicionario
#y ver con un if si esta o no esta, si esta , simplemente imprime
#si no esta lo añade en un dicionario vacio para unirlo a inventario


def agregar_producto(self,nombre,precio,cantidad):
      producto_nuevo={'nombre':nombre,'precio':precio,'cantidad':cantidad}
      for producto in self.inventario:
      
         if nombre == producto['nombre']:
             print('este producto ya estaba, no puedes volver a agregarlo ')

        
      
      else:
               self.inventario.append(producto_nuevo) 
               print(f'el producto {nombre} , ha sido agregado')

# %%
mi_tienda=TiendaOnLine('mitienda')

# %%
mi_tienda.__dict__
# Out:
# {'nombre': 'mitienda',
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto('pantalon',40,60)
mi_tienda.agregar_producto('pantalon',40,60)
#aqui compruebo que se agrega en la primera linea y que el else funciona pq pongo el mismo producto y me dice que no lo puede agregar
# Out:
# el producto pantalon , ha sido agregado
# este producto ya estaba no puedes volver a agregarlo

# %%
mi_tienda.__dict__
#compruebo , solo hay 2 productos
# Out:
# {'nombre': 'mitienda',
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'pantalon', 'precio': 40, 'cantidad': 60}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto('abrigo',60,50)
mi_tienda.agregar_producto('abrigo',60,50)
mi_tienda.agregar_producto('zapatillas',120,1)
# Out:
# el producto abrigo , ha sido agregado
# este producto ya estaba no puedes volver a agregarlo
# el producto zapatillas , ha sido agregado

# %%
mi_tienda.__dict__
# Out:
# {'nombre': 'mitienda',
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'pantalon', 'precio': 40, 'cantidad': 60},
#   {'nombre': 'abrigo', 'precio': 60, 'cantidad': 50},
#   {'nombre': 'zapatillas', 'precio': 120, 'cantidad': 1}],
#  'ventas_totales': 0.0}

# %%
#hasta aqui las comprobaciones del ejercicio 1

# %%
#2. . ver_inventario(self): Muestra el inventario de productos con sus detalles.
#Utiliza un bucle for para recorrer el inventario.
#Imprime los detalles (nombre, precio, cantidad) de cada producto.
#Debería verse
#Nombre: Camisa, Precio: $20, Cantidad: 50
#Nombre: Pantalón, Precio: $30, Cantidad: 30
#Nombre: Zapatos, Precio: $50, Cantidad: 40
#Nombre: Camisa, Precio: $20, Cantidad: 50

def ver_inventario(self):
      for producto in self.inventario:
         print(f'Nombre: {producto['nombre']}, Precio: {producto['precio']}, Cantida: {producto['cantidad']}')

# %%
#comprobamos que el metodo del ejercicio 2 funciona, queda como nos indican y con buena sintaxis

mi_tienda.ver_inventario()
# Out:
# Nombre: camisa, Precio : 20 $, Cantida: 40
# Nombre: pantalon, Precio : 40 $, Cantida: 60
# Nombre: abrigo, Precio : 60 $, Cantida: 50
# Nombre: zapatillas, Precio : 120 $, Cantida: 1

# %%
mi_tienda.ver_inventario()
# Out:
# Nombre: camisa, Precio : 20 $, Cantida: 40
# Nombre: pantalon, Precio : 40 $, Cantida: 60
# Nombre: abrigo, Precio : 60 $, Cantida: 50
# Nombre: zapatillas, Precio : 120 $, Cantida: 1

# %%
#EJERCICIO 3
#. buscar_producto(self, nombre): 
# Busca un producto en el inventario por nombre y muestra susdetalles si se encuentra.
#  Debe recibir el nombre del producto como parámetro.
#Utiliza un bucle for para recorrer el inventario.
#Compara los nombres de los productos con el nombre proporcionado.
#Si se encuentra el producto, imprime sus detalles.
#ebe mostrar:

# %%
def buscar_producto(self,nombre):
       for producto in self.inventario:
           if nombre==producto['nombre']:
               print(f'Nombre:  {producto['nombre']}, Precio $: {producto['precio']}, Cantida: {producto['cantidad']}')
            
               break
       

           else:
             
             print (' el producto , {nombre} , no esta entre las opciones')
             break

# %%
mi_tienda.buscar_producto('camisa')
mi_tienda.buscar_producto('juanito')
# Out:
# Nombre: camisa, Precio $: 20, Cantida: 40
# el "producto" , no esta entre las opciones

# %%
#   EJERCICIO 4

#actualizar_stock(self, nombre, cantidad):
#  Actualiza el stock de un producto en elinventario.
#  Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros.
#Utiliza un bucle for para recorrer el inventario.
#Busca el producto por nombre.
#Actualiza la cantidad según la entrada del usuario.
#Si el producto no esta en el inventario muestra un mensaje indicándolo.

# %%
def actualizar_stock(self,nombre,cantidad):
      
      
      for producto in self.inventario:
         pregunta=(input("que producto quieres actualizar? "))# hago la pregunta de que quiere actualizar

         if pregunta.lower() == producto['nombre']: #entra en el if si lo hace lo actualizara sino a else
            print (f'quieres modificar el producto, {pregunta}')

      
         
            pregunta2=(input("a que cantidad la quieres actualizar? "))
            producto['cantidad'] = pregunta2
            encontrado = True
            print(f"Stock actualizado. Nueva cantidad de {nombre}: es  {producto['cantidad']}")

            print('mi stock actual es: ')#esto lo pongo para comprobar que si se actualizo bien, print de control

            print(f'Nombre: {producto['nombre']}, Precio $: {producto['precio']}, Cantida: {producto['cantidad']}')
            break

         else:
                  print(f'el producto , {pregunta} , no esta en el inventario revisalo porfa')#si no coincide lo que pone con las keys del dicionario
                  break

# %%
mi_tienda.actualizar_stock('camisa',40)
# Out:
# quieres modificar el producto, camisa
# Stock actualizado. Nueva cantidad de camisa: es  25
# mi stock actual es:
# Nombre: camisa, Precio : 20 $, Cantida: 25

# %%
mi_tienda.__dict__#comprobamos que camisa esta actualizada
# Out:
# {'nombre': 'mitienda',
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 25},
#   {'nombre': 'pantalon', 'precio': 40, 'cantidad': 60},
#   {'nombre': 'abrigo', 'precio': 60, 'cantidad': 50},
#   {'nombre': 'zapatillas', 'precio': 120, 'cantidad': 1}],
#  'ventas_totales': 0.0}

# %%
#EJERCICIO 5.
#eliminar_producto(self, nombre): 
# Elimina un producto del inventario por nombre. Deberecibir el nombre del producto como parámetro.
#Utiliza un bucle for para recorrer el inventario.
#busca el producto por nombre.
#Eimina el producto del inventario si existe.
#Si el producto no esta en el inventario muestra un mensaje indicándolo

#muy parecido al ejercicio 4 pero tengo que meterle un .pop

# %%
def eliminar_producto(self, nombre):
         encontrado = False
         for producto in self.inventario:
               if producto['nombre'].lower() == nombre.lower():
                  # Eliminamos el diccionario encontrado de la lista
                  self.inventario.remove(producto) #eliminamos con remove que va bien para dicionarios
                  encontrado = True
                  print(f"Producto '{nombre}' eliminado exitosamente.")
                  break # Salimos del bucle tras eliminar para evitar errores de iteración
         
         if not encontrado:
               print(f"No se encontró el producto '{nombre}', no se pudo eliminar.")

# %%
mi_tienda.eliminar_producto('zapatillas')
# Out:
# Producto 'zapatillas' eliminado exitosamente.

# %%
mi_tienda.__dict__ #comprobamos que ya no esta camisa
# Out:
# {'nombre': 'mitienda',
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 25},
#   {'nombre': 'pantalon', 'precio': 40, 'cantidad': 60},
#   {'nombre': 'abrigo', 'precio': 60, 'cantidad': 50}],
#  'ventas_totales': 0.0}

# %%
#EJERCICIO 6

# %%
# calcular_valor_inventario(self): Calcula y muestra el valor total del inventario.
#Utiliza un bucle for para calcular el valor total del inventario.
#Itera a través del inventario y suma el valor de cada producto (precio x cantidad).
#  Es decir,calcula el valor total del inventario. 
# Ejemplo:
# si tenemos 5 camisas que valen 5 euros
# y 10 calcetines que valen 1 euro
# este método te tiene que devolver: 35 euros

# %%
def calcular_valor_inventario(self):
    valor_total=0 #variable vacia que recibira la multiplicacion de cantidad y precio

    #iteramos 
    for producto in self.inventario:

        valor_producto=producto.int(['precio'])*producto.int(['cantidad'])# como va a iterar, aqui paran cada uno de las multiplicaciones e cada producto

        valor_total+=valor_producto #es la suma de todas las multiplicaciones de valor producto

        print(f'el valor total de todo el "inventario es: {valor_total} €')
        return valor_total
# Out:
# el valor total de todo el "inventario es: 500 €
# 500

# %%
mi_tienda.calcular_valor_inventario()
# Out:
# el valor total de todo el "inventario es: 500 €
# 500

# %%
            #BONUS

# %%
class TiendaOnLine():

    def __init__(self,nombre):
            self.nombre=nombre
            self.clientes={}
            self.inventario=[{'nombre':'camisa','precio':20,'cantidad':40}]
            self.ventas_totales=0.0

        
    def agregar_cliente(self,nombre,email,compras=[]):
                existe=False
                
                for cliente in self.clientes:
                        if cliente['nombre']==nombre:#si el cliente ya esta
                            existe=True
                            print('el cliente ya existia')
                            break
                if existe:
                        print(f'el "cliente {cliente} , ya esta registrado')
                else:
                           cliente_nuevo={
                                  'nombre':nombre,
                                  'email':email,
                                  'compras':compras}
                self.clientes.update(cliente_nuevo)
                           
                            
                print(f'El cliente {nombre} ha sido añadido')

    def ver_clientes(self):
      
      for cliente in self.clientes:
         
         print(f"Nombre : {cliente['nombre']}, email : {cliente['email']}")

# %%
tienda_edu=TiendaOnLine('edu')

# %%
tienda_edu.__dict__
# Out:
# {'nombre': 'edu',
#  'clientes': {},
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
tienda_edu.agregar_cliente('edu','sara@sara.es','v')
# Out:
# El cliente edu ha sido añadido

# %%
tienda_edu.__dict__
# Out:
# {'nombre': 'edu',
#  'clientes': {'nombre': 'edu', 'email': 'sara@sara.es', 'compras': 'v'},
#  'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
#BONUS 2

#ver_clientes(self): Muestra la lista de clientes registrados con sus nombres y correos

#Utiliza un bucle for para recorrer la base de datos de clientes.
#Imprime los detalles de cada cliente (nombre y correo electrónico).
#
def ver_clientes(self):
      for cliente in self.clientes:
         print(f"Nombre : {cliente['nombre']}, email : {cliente['email']}")

# %%
tienda_edu.ver_clientes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 tienda_edu.ver_clientes()
#
# AttributeError: 'TiendaOnLine' object has no attribute 'ver_clientes'
